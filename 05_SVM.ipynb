# %% [markdown]
# ### 1.  Import Required Libraries
# Import the necessary libraries, including NumPy, sklearn.svm, and matplotlib.pyplot.

# %%
# Importing the required libraries
import numpy as np
from sklearn.svm import SVC
import matplotlib.pyplot as plt
from sklearn import svm
from sklearn.datasets import make_blobs

# %% [markdown]
# ### 2.  Create Linearly Separable Points
# Use the make_blobs function from sklearn.datasets to create a set of linearly separable points.
#
# ### Visualize the Points
# Use matplotlib to create a scatter plot of the points, color-coded by class.

# %%
# Create linearly separable points
X, y = make_blobs(n_samples=18, centers=[(2, 2), (5, 5)])

# Question for students: What does the 'centers' parameter do in the make_blobs function?
# Exercise for students: Try changing the 'centers' parameter to create different datasets. What happens when you change the number of centers or their coordinates?

# Visualize the points
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
plt.title('Scatter plot of the points')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# Question for students: What can you infer from the scatter plot about the distribution of the two classes?
# Exercise for students: Try changing the 'cmap' parameter in the scatter function to use different color maps. How does this affect the visualization?

# %% [markdown]
# ### 3.  Fit the SVM Model
# Create an instance of the SVC class with a linear kernel and a large C parameter, then fit it to the data.

# %%
# Create an instance of the SVC class
svm = SVC(kernel='linear', C=10**15)

# Fit the model to the data
svm.fit(X, y)
# Out:
# SVC(C=1000000000000000, kernel='linear')

# %% [markdown]
# ### 4.  Visualize the Dataset and SVM Decision Boundary
# Plot the dataset and the decision boundary of the SVM, including the margins and the support vectors.

# %%
# Plot the dataset
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, s=30, cmap=plt.cm.Paired)
plt.title('Scatter plot of the points with SVM decision boundary')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')

# Plot the decision function
ax = plt.gca()
xlim = ax.get_xlim()
ylim = ax.get_ylim()

# Create grid to evaluate model
xx = np.linspace(xlim[0], xlim[1], 30)
yy = np.linspace(ylim[0], ylim[1], 30)
YY, XX = np.meshgrid(yy, xx)
xy = np.vstack([XX.ravel(), YY.ravel()]).T
Z = svm.decision_function(xy).reshape(XX.shape)

# Plot decision boundary and margins
ax.contour(XX, YY, Z, colors='k', levels=[-1, 0, 1], alpha=0.5, linestyles=['--', '-', '--'])

# Plot support vectors
ax.scatter(svm.support_vectors_[:, 0], svm.support_vectors_[:, 1], s=100, facecolors='none', edgecolors='k')
plt.show()

# Question for students: What are support vectors and why are they important in SVM?

# %% [markdown]
# ### 5.  Questions and Exercises
# Include questions about the code and exercises that prompt students to modify the hyperparameters of the SVM model.

# %%
# Question 1: What does the 'centers' parameter do in the make_blobs function?

# Exercise 1: Try changing the 'centers' parameter to create different datasets. 
# What happens when you change the number of centers or their coordinates?
# Answer: Students should try this on their own.

# Question 2: What can you infer from the scatter plot about the distribution of the two classes?

# Question 4: What does the 'C' parameter control in the SVC class? 
# Answer: The 'C' parameter controls the penalty for misclassification.

# Exercise 4: Try changing the 'C' parameter to different values. 
# How does this affect the decision boundary and the number of support vectors?
# Answer: Students should try this on their own.

# Question 5: What are support vectors and why are they important in SVM?

# Exercise 5: Try changing the 'C' parameter to a very small value. 
# How does this affect the number of support vectors?
# Answer: Students should try this on their own.
